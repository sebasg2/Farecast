# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import joblib
import tensorflow as tf

modelo = joblib.load('final_model.pkl')
modelo1=joblib.load('final_model_nmd.pkl')

# %%
airports_dict = {
    "Afghanistan": "KBL",
    "Albania": "TIA",
    "Algeria": "ALG",
    "Andorra": "LEU",
    "Angola": "LAD",
    "Antigua and Barbuda": "ANU",
    "Argentina": "EZE",
    "Armenia": "EVN",
    "Australia": "SYD",
    "Austria": "VIE",
    "Azerbaijan": "GYD",
    "Bahamas": "NAS",
    "Bahrain": "BAH",
    "Bangladesh": "DAC",
    "Barbados": "BGI",
    "Belarus": "MSQ",
    "Belgium": "BRU",
    "Belize": "BZE",
    "Benin": "COO",
    "Bhutan": "PBH",
    "Bolivia": "VVI",
    "Bosnia and Herzegovina": "SJJ",
    "Botswana": "GBE",
    "Brazil": "GRU",
    "Brunei Darussalam": "BWN",
    "Bulgaria": "SOF",
    "Burkina Faso": "OUA",
    "Burundi": "BJM",
    "Cabo Verde": "SID",
    "Cambodia": "PNH",
    "Cameroon": "DLA",
    "Canada": "YYZ",
    "Central African Republic": "BGF",
    "Chad": "NDJ",
    "Chile": "SCL",
    "China": "PEK",
    "Colombia": "BOG",
    "Comoros": "HAH",
    "Congo": "FIH",
    "Costa Rica": "SJO",
    "Ivory Coast": "ABJ",
    "Croatia": "ZAG",
    "Cuba": "HAV",
    "Cyprus": "LCA",
    "Czech Republic": "PRG",
    "South Korea": "FNJ",
    "Congo": "FIH",
    "Denmark": "CPH",
    "Djibouti": "JIB",
    "Dominica": "DOM",
    "Dominican Republic": "SDQ",
    "Ecuador": "UIO",
    "Egypt": "CAI",
    "El Salvador": "SAL",
    "Equatorial Guinea": "SSG",
    "Eritrea": "ASM",
    "Estonia": "TLL",
    "Eswatini": "MTS",
    "Ethiopia": "ADD",
    "Fiji": "NAN",
    "Finland": "HEL",
    "France": "CDG",
    "Gabon": "LBV",
    "Gambia": "BJL",
    "Georgia": "TBS",
    "Germany": "FRA",
    "Ghana": "ACC",
    "Greece": "ATH",
    "Grenada": "GND",
    "Guatemala": "GUA",
    "Guinea": "CKY",
    "Guinea Bissau": "OXB",
    "Guyana": "GEO",
    "Haiti": "PAP",
    "Honduras": "SAP",
    "Hungary": "BUD",
    "Iceland": "KEF",
    "India": "DEL",
    "Indonesia": "CGK",
    "Iran": "THR",
    "Iraq": "BGW",
    "Ireland": "DUB",
    "Israel": "TLV",
    "Italy": "FCO",
    "Jamaica": "SIA",
    "Japan": "NRT",
    "Jordan": "AMM",
    "Kazakhstan": "ALA",
    "Kenya": "NBO",
    "Kiribati": "TRW",
    "Kuwait": "KWI",
    "Kyrgyzstan": "FRU",
    "Lao": "VTE",
    "Latvia": "RIX",
    "Lebanon": "BEY",
    "Lesotho": "MSU",
    "Liberia": "ROB",
    "Libya": "TIP",
    "Liechtenstein": "LI",
    "Lithuania": "VNO",
    "Luxembourg": "LUX",
    "Madagascar": "TNR",
    "Malawi": "LLW",
    "Malaysia": "KUL",
    "Maldives": "MLE",
    "Mali": "BKO",
    "Malta": "MLA",
    "Marshall Islands": "MAJ",
    "Mauritania": "NKC",
    "Mauritius": "MRU",
    "Mexico": "MEX",
    "Micronesia": "KSA",
    "Monaco": "MUC",
    "Mongolia": "ULN",
    "Montenegro": "TIV",
    "Morocco": "CMN",
    "Mozambique": "LUM",
    "Myanmar": "RGN",
    "Namibia": "WDH",
    "Nauru": "INU",
    "Nepal": "LUA",
    "Netherlands": "AMS",
    "New Zealand": "AKL",
    "Nicaragua": "MGA",
    "Niger": "NIM",
    "Nigeria": "LOS",
    "North Macedonia": "SKP",
    "Norway": "OSL",
    "Oman": "MCT",
    "Pakistan": "KHI",
    "Palau": "ROR",
    "Panama": "PTY",
    "Papua New Guinea": "POM",
    "Paraguay": "ASU",
    "Peru": "LIM",
    "Philippines": "MNL",
    "Poland": "WAW",
    "Portugal": "LIS",
    "Qatar": "DOH",
    "Republic of Korea": "IIA",
    "Republic of Moldova": "KIV",
    "Romania": "OTP",
    "Russian Federation": "SVO",
    "Rwanda": "KGL",
    "Saint Kitts and Nevis": "SKB",
    "Saint Lucia": "UVF",
    "Saint Vincent and the Grenadines": "SVD",
    "Samoa": "APW",
    "San Marino": "RMI",
    "Sao Tome and Principe": "TMS",
    "Saudi Arabia": "DMM",
    "Senegal": "DSS",
    "Serbia": "BEG",
    "Seychelles": "SEZ",
    "Sierra Leone": "FNA",
    "Singapore": "SIN",
    "Slovakia": "BTS",
    "Slovenia": "LJU",
    "Solomon Islands": "HIR",
    "Somalia": "MGQ",
    "South Africa": "JNB",
    "South Sudan": "JUB",
    "Spain": "MAD",
    "Sri Lanka": "CMB",
    "Sudan": "KRT",
    "Suriname": "PBM",
    "Sweden": "ARN",
    "Switzerland": "ZRH",
    "Syrian Arab Republic": "DAM",
    "Tajikistan": "DYU",
    "Thailand": "BKK",
    "Timor-Leste": "DIL",
    "Togo": "LFW",
    "Tonga": "TBU",
    "Trinidad and Tobago": "POS",
    "Tunisia": "TUN",
    "Turkey": "IST",
    "Turkmenistan": "ASB",
    "Tuvalu": "FUN",
    "Uganda": "EBB",
    "Ukraine": "KBP",
    "United Arab Emirates": "DXB",
    "United Kingdom": "LHR",
    "United Republic of Tanzania": "DAR",
    "United States of America": "DEN",
    "Uruguay": "MVD",
    "Uzbekistan": "TAS",
    "Vanuatu": "VLI",
    "Venezuela": "CCS",
    "Viet Nam": "SGN",
    "Yemen": "SAH",
    "Zambia": "LUN",
    "Zimbabwe": "HRE"
}

# %%
def get_airport_coordinates(country):
    import airportsdata
    
    airports = airportsdata.load('IATA')
    iata_code = airports_dict.get(country)
    print(iata_code)
    if iata_code:
        airport = airports.get(iata_code)
        if airport:
            return airport['lat'], airport['lon']
    return None, None

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in kilometers
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    return distance

# %%
def calculate_distance(row):
    
    origin_lat, origin_lon = get_airport_coordinates(row['Origin_Country'])
    destination_lat, destination_lon = get_airport_coordinates(row['Destination_Country'])
    if origin_lat is not None and destination_lat is not None:
        return haversine(origin_lat, origin_lon, destination_lat, destination_lon)
    return None

# %%
def map_to_continent(country_name):
    
    from Countrydetails import countries
    
    country = countries.all_countries()
    continent_countries_dict=country.countries_in_continents()
    
    try:
        # Iterate through the dictionary to find the continent
        for continent, countries_list in continent_countries_dict.items():
            if country_name in countries_list:
                return continent
        return 'Unknown'  # Return 'Unknown' if country not found in the dictionary
    except Exception as e:
        print(f"Error mapping {country_name} to continent: {e}")
        return 'Unknown'

# %%
def calculate_flight_duration(distance_km):
    # Velocidad promedio de un avión comercial en km/h
    average_speed_kmh = 900
    if distance_km is None:
        return None

    # Calcular la duración en horas
    duration_hours = distance_km / average_speed_kmh

    # Convertir la duración a decimal
    hours = int(duration_hours)
    minutes = (duration_hours - hours) * 60
    duration_decimal = hours + (minutes / 60)

    return round(duration_decimal, 2)

# %%
columns_with_dummies = [
    'Airline Code_2J',
    'Airline Code_3K',
    'Airline Code_3M',
    'Airline Code_3U',
    'Airline Code_4Y',
    'Airline Code_4Z',
    'Airline Code_5F',
    'Airline Code_5U',
    'Airline Code_5Z',
    'Airline Code_6H',
    'Airline Code_6X',
    'Airline Code_7C',
    'Airline Code_8M',
    'Airline Code_A1',
    'Airline Code_A3',
    'Airline Code_AC',
    'Airline Code_AD',
    'Airline Code_AF',
    'Airline Code_AH',
    'Airline Code_AI',
    'Airline Code_AR',
    'Airline Code_AS',
    'Airline Code_AT',
    'Airline Code_AV',
    'Airline Code_AY',
    'Airline Code_AZ',
    'Airline Code_B6',
    'Airline Code_BG',
    'Airline Code_BI',
    'Airline Code_BJ',
    'Airline Code_BP',
    'Airline Code_BR',
    'Airline Code_BT',
    'Airline Code_BW',
    'Airline Code_CA',
    'Airline Code_CI',
    'Airline Code_CM',
    'Airline Code_CU',
    'Airline Code_CX',
    'Airline Code_CZ',
    'Airline Code_D8',
    'Airline Code_DE',
    'Airline Code_DO',
    'Airline Code_DT',
    'Airline Code_DY',
    'Airline Code_EI',
    'Airline Code_EK',
    'Airline Code_EN',
    'Airline Code_ET',
    'Airline Code_EW',
    'Airline Code_EY',
    'Airline Code_FA',
    'Airline Code_FB',
    'Airline Code_FI',
    'Airline Code_FJ',
    'Airline Code_FM',
    'Airline Code_FN',
    'Airline Code_FZ',
    'Airline Code_G3',
    'Airline Code_GA',
    'Airline Code_GF',
    'Airline Code_GK',
    'Airline Code_H1',
    'Airline Code_HA',
    'Airline Code_HC',
    'Airline Code_HF',
    'Airline Code_HM',
    'Airline Code_HO',
    'Airline Code_HU',
    'Airline Code_HX',
    'Airline Code_HY',
    'Airline Code_IB',
    'Airline Code_ID',
    'Airline Code_IE',
    'Airline Code_J2',
    'Airline Code_JD',
    'Airline Code_JL',
    'Airline Code_JQ',
    'Airline Code_JU',
    'Airline Code_JY',
    'Airline Code_K6',
    'Airline Code_KC',
    'Airline Code_KE',
    'Airline Code_KL',
    'Airline Code_KM',
    'Airline Code_KP',
    'Airline Code_KQ',
    'Airline Code_KR',
    'Airline Code_KU',
    'Airline Code_L6',
    'Airline Code_LA',
    'Airline Code_LG',
    'Airline Code_LH',
    'Airline Code_LO',
    'Airline Code_LX',
    'Airline Code_LY',
    'Airline Code_ME',
    'Airline Code_MF',
    'Airline Code_MH',
    'Airline Code_MK',
    'Airline Code_MS',
    'Airline Code_MU',
    'Airline Code_NF',
    'Airline Code_NH',
    'Airline Code_NK',
    'Airline Code_NZ',
    'Airline Code_OB',
    'Airline Code_OD',
    'Airline Code_OK',
    'Airline Code_OM',
    'Airline Code_OR',
    'Airline Code_OS',
    'Airline Code_OU',
    'Airline Code_OZ',
    'Airline Code_P0',
    'Airline Code_P4',
    'Airline Code_PC',
    'Airline Code_PG',
    'Airline Code_PK',
    'Airline Code_PR',
    'Airline Code_PU',
    'Airline Code_PW',
    'Airline Code_PX',
    'Airline Code_PY',
    'Airline Code_QF',
    'Airline Code_QR',
    'Airline Code_QS',
    'Airline Code_QV',
    'Airline Code_RJ',
    'Airline Code_RN',
    'Airline Code_RO',
    'Airline Code_RQ',
    'Airline Code_SA',
    'Airline Code_SB',
    'Airline Code_SC',
    'Airline Code_SG',
    'Airline Code_SK',
    'Airline Code_SL',
    'Airline Code_SN',
    'Airline Code_SQ',
    'Airline Code_SS',
    'Airline Code_SV',
    'Airline Code_TC',
    'Airline Code_TG',
    'Airline Code_TK',
    'Airline Code_TM',
    'Airline Code_TP',
    'Airline Code_TR',
    'Airline Code_TU',
    'Airline Code_UA',
    'Airline Code_UB',
    'Airline Code_UK',
    'Airline Code_UL',
    'Airline Code_UP',
    'Airline Code_UR',
    'Airline Code_UU',
    'Airline Code_UX',
    'Airline Code_VA',
    'Airline Code_VB',
    'Airline Code_VF',
    'Airline Code_VN',
    'Airline Code_VS',
    'Airline Code_VY',
    'Airline Code_W2',
    'Airline Code_W3',
    'Airline Code_WB',
    'Airline Code_WF',
    'Airline Code_WM',
    'Airline Code_WS',
    'Airline Code_WY',
    'Airline Code_X1',
    'Airline Code_XY',
    'Airline Code_ZB',
    'Airline Code_ZH',
    'Airline Code_ZL',
    'Airline Code_ZP',
    'Origin Continent_Africa',
    'Origin Continent_Asia',
    'Origin Continent_Europe',
    'Origin Continent_North America',
    'Origin Continent_Oceania',
    'Origin Continent_South America',
    'Destination Continent_Africa',
    'Destination Continent_Asia',
    'Destination Continent_Europe',
    'Destination Continent_North America',
    'Destination Continent_Oceania',
    'Destination Continent_South America',
    'Flight_Distance_Category_Long Haul',
    'Flight_Distance_Category_Medium Haul',
    'Flight_Distance_Category_Short Haul',
    'Flight_Duration_Category_Long',
    'Flight_Duration_Category_Medium',
    'Flight_Duration_Category_Short',
 
]

# %%
# Suprimir todas las advertencias
warnings.filterwarnings('ignore')

# %% [markdown]
# Predecir individual con mes y dia

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

# Assuming 'modelo' is your pre-loaded model and 'columns_with_dummies' is a list of expected columns after one-hot encoding

def predecir(Hour_of_Departure, airline, Stops, Origin_Country, Destination_Country, day, month, year):
    
    def categorize_flight_duration(duration):
        return pd.cut(duration, bins=[-np.inf, 12, 24, np.inf], labels=['Short', 'Medium', 'Long'])

    def categorize_flight_distance(distance):
        return pd.cut(distance, bins=[-np.inf, 4000, 7500, np.inf], labels=['Short Haul', 'Medium Haul', 'Long Haul'])

    def days_until_flight(departure_time):
        now = datetime.now()
        departure_date = datetime(year, month, day, Hour_of_Departure)
        days_difference = (departure_date - now).days
        return days_difference

    input_data = {
        'Hour_of_Departure': [Hour_of_Departure],
        'Airline': [airline],
        'Number of Stops': [Stops],
        'Origin_Country': [Origin_Country],
        'Destination_Country': [Destination_Country],
        'Month': [month],
        'Day': [day]
    }
    
    input_df = pd.DataFrame(input_data)

    # Calculate distance and flight duration
    input_df['Distance (km)'] = calculate_distance(input_df.iloc[0])
    input_df['Duration'] = calculate_flight_duration(input_df['Distance (km)'])

    # Determine Flight_Duration_Category based on duration
    input_df['Flight_Duration_Category'] = categorize_flight_duration(input_df['Duration'])

    # Determine Direct_Flight based on stops
    input_df['Is_Direct_Flight'] = input_df['Number of Stops'].apply(lambda x: 1 if x == 0 else 0)

    # Determine Flight_Distance_Category based on distance
    input_df['Flight_Distance_Category'] = categorize_flight_distance(input_df['Distance (km)'])

    # Map countries to continents
    input_df['Origin Continent'] = input_df['Origin_Country'].apply(map_to_continent)
    input_df['Destination Continent'] = input_df['Destination_Country'].apply(map_to_continent)

    # Get dummies for categorical variables
    columns_to_dummy = ['Airline', 'Origin Continent', 'Destination Continent', 'Flight_Duration_Category', 'Flight_Distance_Category']
    dummy_df = pd.get_dummies(input_df[columns_to_dummy], drop_first=True, dtype=float)
    
    # Concatenate the original input_df with the dummy columns
    input_df = pd.concat([input_df.drop(columns_to_dummy, axis=1), dummy_df], axis=1)

    # Ensure the input_df has the same columns as the expected columns with dummies
    missing_cols = set(columns_with_dummies) - set(input_df.columns)
    for col in missing_cols:
        input_df[col] = 0

    # Calculate days until flight
    departure_date = datetime(year, month, day, Hour_of_Departure)
    input_df['Days_Until_Flight'] = days_until_flight(departure_date)

    # Determine if it's an extra long flight
    input_df['Extra_Long_Flight'] = (input_df['Duration'] > 40).astype(float)  # Example threshold for extra long flight

    input_df = input_df[[
        'Duration', 'Number of Stops', 'Distance (km)', 'Hour_of_Departure', 'Is_Direct_Flight',
        'Month', 'Day', 'Airline Code_2J', 'Airline Code_3K', 'Airline Code_3M', 'Airline Code_3U', 
        'Airline Code_4Y', 'Airline Code_4Z', 'Airline Code_5F', 'Airline Code_5U', 'Airline Code_5Z',
        'Airline Code_6H', 'Airline Code_6X', 'Airline Code_7C', 'Airline Code_8M', 'Airline Code_A1',
        'Airline Code_A3', 'Airline Code_AC', 'Airline Code_AD', 'Airline Code_AF', 'Airline Code_AH',
        'Airline Code_AI', 'Airline Code_AR', 'Airline Code_AS', 'Airline Code_AT', 'Airline Code_AV',
        'Airline Code_AY', 'Airline Code_AZ', 'Airline Code_B6', 'Airline Code_BG', 'Airline Code_BI',
        'Airline Code_BJ', 'Airline Code_BP', 'Airline Code_BR', 'Airline Code_BT', 'Airline Code_BW',
        'Airline Code_CA', 'Airline Code_CI', 'Airline Code_CM', 'Airline Code_CU', 'Airline Code_CX',
        'Airline Code_CZ', 'Airline Code_D8', 'Airline Code_DE', 'Airline Code_DO', 'Airline Code_DT',
        'Airline Code_DY', 'Airline Code_EI', 'Airline Code_EK', 'Airline Code_EN', 'Airline Code_ET',
        'Airline Code_EW', 'Airline Code_EY', 'Airline Code_FA', 'Airline Code_FB', 'Airline Code_FI',
        'Airline Code_FJ', 'Airline Code_FM', 'Airline Code_FN', 'Airline Code_FZ', 'Airline Code_G3',
        'Airline Code_GA', 'Airline Code_GF', 'Airline Code_GK', 'Airline Code_H1', 'Airline Code_HA',
        'Airline Code_HC', 'Airline Code_HF', 'Airline Code_HM', 'Airline Code_HO', 'Airline Code_HU',
        'Airline Code_HX', 'Airline Code_HY', 'Airline Code_IB', 'Airline Code_ID', 'Airline Code_IE',
        'Airline Code_J2', 'Airline Code_JD', 'Airline Code_JL', 'Airline Code_JQ', 'Airline Code_JU',
        'Airline Code_JY', 'Airline Code_K6', 'Airline Code_KC', 'Airline Code_KE', 'Airline Code_KL',
        'Airline Code_KM', 'Airline Code_KP', 'Airline Code_KQ', 'Airline Code_KR', 'Airline Code_KU',
        'Airline Code_L6', 'Airline Code_LA', 'Airline Code_LG', 'Airline Code_LH', 'Airline Code_LO',
        'Airline Code_LX', 'Airline Code_LY', 'Airline Code_ME', 'Airline Code_MF', 'Airline Code_MH',
        'Airline Code_MK', 'Airline Code_MS', 'Airline Code_MU', 'Airline Code_NF', 'Airline Code_NH',
        'Airline Code_NK', 'Airline Code_NZ', 'Airline Code_OB', 'Airline Code_OD', 'Airline Code_OK',
        'Airline Code_OM', 'Airline Code_OR', 'Airline Code_OS', 'Airline Code_OU', 'Airline Code_OZ',
        'Airline Code_P0', 'Airline Code_P4', 'Airline Code_PC', 'Airline Code_PG', 'Airline Code_PK',
        'Airline Code_PR', 'Airline Code_PU', 'Airline Code_PW', 'Airline Code_PX', 'Airline Code_PY',
        'Airline Code_QF', 'Airline Code_QR', 'Airline Code_QS', 'Airline Code_QV', 'Airline Code_RJ',
        'Airline Code_RN', 'Airline Code_RO', 'Airline Code_RQ', 'Airline Code_SA', 'Airline Code_SB',
        'Airline Code_SC', 'Airline Code_SG', 'Airline Code_SK', 'Airline Code_SL', 'Airline Code_SN',
        'Airline Code_SQ', 'Airline Code_SS', 'Airline Code_SV', 'Airline Code_TC', 'Airline Code_TG',
        'Airline Code_TK', 'Airline Code_TM', 'Airline Code_TP', 'Airline Code_TR', 'Airline Code_TU',
        'Airline Code_UA', 'Airline Code_UB', 'Airline Code_UK', 'Airline Code_UL', 'Airline Code_UP',
        'Airline Code_UR', 'Airline Code_UU', 'Airline Code_UX', 'Airline Code_VA', 'Airline Code_VB',
        'Airline Code_VF', 'Airline Code_VN', 'Airline Code_VS', 'Airline Code_VY', 'Airline Code_W2',
        'Airline Code_W3', 'Airline Code_WB', 'Airline Code_WF', 'Airline Code_WM', 'Airline Code_WS',
        'Airline Code_WY', 'Airline Code_X1', 'Airline Code_XY', 'Airline Code_ZB', 'Airline Code_ZH',
        'Airline Code_ZL', 'Airline Code_ZP', 'Origin Continent_Africa', 'Origin Continent_Asia',
        'Origin Continent_Europe', 'Origin Continent_North America', 'Origin Continent_Oceania',
        'Origin Continent_South America', 'Destination Continent_Africa', 'Destination Continent_Asia',
        'Destination Continent_Europe', 'Destination Continent_North America', 'Destination Continent_Oceania',
        'Destination Continent_South America', 'Flight_Distance_Category_Long Haul',
        'Flight_Distance_Category_Medium Haul', 'Flight_Distance_Category_Short Haul',
        'Flight_Duration_Category_Long', 'Flight_Duration_Category_Medium', 'Flight_Duration_Category_Short',
        'Days_Until_Flight', 'Extra_Long_Flight'
    ]]

    input_df = input_df.select_dtypes(include=[int, float])
    y_pred = modelo.predict(input_df)

    return y_pred

# Example usage
predicted_price = predecir(Hour_of_Departure=18, airline='AF', Stops=1, Origin_Country='Spain', Destination_Country='Japan', day=2, month=8, year=2024)
print(predicted_price)

# %% [markdown]
# Predecir individual sin mes y dua

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

# Assuming 'modelo' is your pre-loaded model and 'columns_with_dummies' is a list of expected columns after one-hot encoding

def predecir_nmd(Hour_of_Departure, airline, Stops, Origin_Country, Destination_Country, day, month, year):
    
    def categorize_flight_duration(duration):
        return pd.cut(duration, bins=[-np.inf, 12, 24, np.inf], labels=['Short', 'Medium', 'Long'])

    def categorize_flight_distance(distance):
        return pd.cut(distance, bins=[-np.inf, 4000, 7500, np.inf], labels=['Short Haul', 'Medium Haul', 'Long Haul'])

    def days_until_flight(departure_time):
        now = datetime.now()
        departure_date = datetime(year, month, day, Hour_of_Departure)
        days_difference = (departure_date - now).days
        return days_difference

    input_data = {
        'Hour_of_Departure': [Hour_of_Departure],
        'Airline': [airline],
        'Number of Stops': [Stops],
        'Origin_Country': [Origin_Country],
        'Destination_Country': [Destination_Country],
    }
    
    input_df = pd.DataFrame(input_data)

    # Calculate distance and flight duration
    input_df['Distance (km)'] = calculate_distance(input_df.iloc[0])
    input_df['Duration'] = calculate_flight_duration(input_df['Distance (km)'])

    # Determine Flight_Duration_Category based on duration
    input_df['Flight_Duration_Category'] = categorize_flight_duration(input_df['Duration'])

    # Determine Direct_Flight based on stops
    input_df['Is_Direct_Flight'] = input_df['Number of Stops'].apply(lambda x: 1 if x == 0 else 0)

    # Determine Flight_Distance_Category based on distance
    input_df['Flight_Distance_Category'] = categorize_flight_distance(input_df['Distance (km)'])

    # Map countries to continents
    input_df['Origin Continent'] = input_df['Origin_Country'].apply(map_to_continent)
    input_df['Destination Continent'] = input_df['Destination_Country'].apply(map_to_continent)

    # Get dummies for categorical variables
    columns_to_dummy = ['Airline', 'Origin Continent', 'Destination Continent', 'Flight_Duration_Category', 'Flight_Distance_Category']
    dummy_df = pd.get_dummies(input_df[columns_to_dummy], drop_first=True, dtype=float)
    
    # Concatenate the original input_df with the dummy columns
    input_df = pd.concat([input_df.drop(columns_to_dummy, axis=1), dummy_df], axis=1)

    # Ensure the input_df has the same columns as the expected columns with dummies
    missing_cols = set(columns_with_dummies) - set(input_df.columns)
    for col in missing_cols:
        input_df[col] = 0

    # Calculate days until flight
    departure_date = datetime(year, month, day, Hour_of_Departure)
    input_df['Days_Until_Flight'] = days_until_flight(departure_date)

    # Determine if it's an extra long flight
    input_df['Extra_Long_Flight'] = (input_df['Duration'] > 40).astype(float)  # Example threshold for extra long flight

    input_df = input_df[[
        'Duration', 'Number of Stops', 'Distance (km)', 'Hour_of_Departure', 'Is_Direct_Flight',
        'Airline Code_2J', 'Airline Code_3K', 'Airline Code_3M', 'Airline Code_3U', 
        'Airline Code_4Y', 'Airline Code_4Z', 'Airline Code_5F', 'Airline Code_5U', 'Airline Code_5Z',
        'Airline Code_6H', 'Airline Code_6X', 'Airline Code_7C', 'Airline Code_8M', 'Airline Code_A1',
        'Airline Code_A3', 'Airline Code_AC', 'Airline Code_AD', 'Airline Code_AF', 'Airline Code_AH',
        'Airline Code_AI', 'Airline Code_AR', 'Airline Code_AS', 'Airline Code_AT', 'Airline Code_AV',
        'Airline Code_AY', 'Airline Code_AZ', 'Airline Code_B6', 'Airline Code_BG', 'Airline Code_BI',
        'Airline Code_BJ', 'Airline Code_BP', 'Airline Code_BR', 'Airline Code_BT', 'Airline Code_BW',
        'Airline Code_CA', 'Airline Code_CI', 'Airline Code_CM', 'Airline Code_CU', 'Airline Code_CX',
        'Airline Code_CZ', 'Airline Code_D8', 'Airline Code_DE', 'Airline Code_DO', 'Airline Code_DT',
        'Airline Code_DY', 'Airline Code_EI', 'Airline Code_EK', 'Airline Code_EN', 'Airline Code_ET',
        'Airline Code_EW', 'Airline Code_EY', 'Airline Code_FA', 'Airline Code_FB', 'Airline Code_FI',
        'Airline Code_FJ', 'Airline Code_FM', 'Airline Code_FN', 'Airline Code_FZ', 'Airline Code_G3',
        'Airline Code_GA', 'Airline Code_GF', 'Airline Code_GK', 'Airline Code_H1', 'Airline Code_HA',
        'Airline Code_HC', 'Airline Code_HF', 'Airline Code_HM', 'Airline Code_HO', 'Airline Code_HU',
        'Airline Code_HX', 'Airline Code_HY', 'Airline Code_IB', 'Airline Code_ID', 'Airline Code_IE',
        'Airline Code_J2', 'Airline Code_JD', 'Airline Code_JL', 'Airline Code_JQ', 'Airline Code_JU',
        'Airline Code_JY', 'Airline Code_K6', 'Airline Code_KC', 'Airline Code_KE', 'Airline Code_KL',
        'Airline Code_KM', 'Airline Code_KP', 'Airline Code_KQ', 'Airline Code_KR', 'Airline Code_KU',
        'Airline Code_L6', 'Airline Code_LA', 'Airline Code_LG', 'Airline Code_LH', 'Airline Code_LO',
        'Airline Code_LX', 'Airline Code_LY', 'Airline Code_ME', 'Airline Code_MF', 'Airline Code_MH',
        'Airline Code_MK', 'Airline Code_MS', 'Airline Code_MU', 'Airline Code_NF', 'Airline Code_NH',
        'Airline Code_NK', 'Airline Code_NZ', 'Airline Code_OB', 'Airline Code_OD', 'Airline Code_OK',
        'Airline Code_OM', 'Airline Code_OR', 'Airline Code_OS', 'Airline Code_OU', 'Airline Code_OZ',
        'Airline Code_P0', 'Airline Code_P4', 'Airline Code_PC', 'Airline Code_PG', 'Airline Code_PK',
        'Airline Code_PR', 'Airline Code_PU', 'Airline Code_PW', 'Airline Code_PX', 'Airline Code_PY',
        'Airline Code_QF', 'Airline Code_QR', 'Airline Code_QS', 'Airline Code_QV', 'Airline Code_RJ',
        'Airline Code_RN', 'Airline Code_RO', 'Airline Code_RQ', 'Airline Code_SA', 'Airline Code_SB',
        'Airline Code_SC', 'Airline Code_SG', 'Airline Code_SK', 'Airline Code_SL', 'Airline Code_SN',
        'Airline Code_SQ', 'Airline Code_SS', 'Airline Code_SV', 'Airline Code_TC', 'Airline Code_TG',
        'Airline Code_TK', 'Airline Code_TM', 'Airline Code_TP', 'Airline Code_TR', 'Airline Code_TU',
        'Airline Code_UA', 'Airline Code_UB', 'Airline Code_UK', 'Airline Code_UL', 'Airline Code_UP',
        'Airline Code_UR', 'Airline Code_UU', 'Airline Code_UX', 'Airline Code_VA', 'Airline Code_VB',
        'Airline Code_VF', 'Airline Code_VN', 'Airline Code_VS', 'Airline Code_VY', 'Airline Code_W2',
        'Airline Code_W3', 'Airline Code_WB', 'Airline Code_WF', 'Airline Code_WM', 'Airline Code_WS',
        'Airline Code_WY', 'Airline Code_X1', 'Airline Code_XY', 'Airline Code_ZB', 'Airline Code_ZH',
        'Airline Code_ZL', 'Airline Code_ZP', 'Origin Continent_Africa', 'Origin Continent_Asia',
        'Origin Continent_Europe', 'Origin Continent_North America', 'Origin Continent_Oceania',
        'Origin Continent_South America', 'Destination Continent_Africa', 'Destination Continent_Asia',
        'Destination Continent_Europe', 'Destination Continent_North America', 'Destination Continent_Oceania',
        'Destination Continent_South America', 'Flight_Distance_Category_Long Haul',
        'Flight_Distance_Category_Medium Haul', 'Flight_Distance_Category_Short Haul',
        'Flight_Duration_Category_Long', 'Flight_Duration_Category_Medium', 'Flight_Duration_Category_Short',
        'Days_Until_Flight', 'Extra_Long_Flight'
    ]]

    input_df = input_df.select_dtypes(include=[int, float])
    y_pred = modelo1.predict(input_df)

    return y_pred

# Example usage
predicted_price = predecir_nmd(Hour_of_Departure=18, airline='AF', Stops=1, Origin_Country='Spain', Destination_Country='Japan', day=2, month=8, year=2024)
print(predicted_price)
# Out:
# MAD
# NRT
# [676.4586878]

# %% [markdown]
# Con mes y dia

# %%
from datetime import datetime, timedelta
import numpy as np
import warnings

# Suprimir todas las advertencias
warnings.filterwarnings('ignore')

def calculate_distance_two(origin_country, destination_country):
    origin_lat, origin_lon = get_airport_coordinates(origin_country)
    destination_lat, destination_lon = get_airport_coordinates(destination_country)
    
    if origin_lat is not None and destination_lat is not None:
        return haversine(origin_lat, origin_lon, destination_lat, destination_lon)
    
    return None

def determine_if_stop_needed(distance):
    # Definir el umbral de distancia para requerir una parada
    stop_threshold = 6437.376  # Ejemplo de umbral en kilómetros

    # Determinar si se necesita una parada según la distancia
    if distance > stop_threshold:
        return True
    else:
        return False

def find_best_travel_time(origin, destination):
    best_month = None
    best_day = None
    best_hour = None

    # Inicializar una lista vacía para almacenar los precios medios por mes
    mean_prices_by_month = []

    # Calcular el rango de fechas desde hoy hasta un año a partir de ahora
    start_date = datetime.now()
    end_date = start_date + timedelta(days=365)  # Un año desde ahora

    day_of_month=np.arange(1,30)
    # Días representativos (1 por mes)
    days_in_range = []
    for i in range(9):  # Ajustar el número de días representativos según sea necesario
        # Calcular el día para cada mes representativo
        month_date = start_date + timedelta(days=i * 30)  # Aproximación de días en un mes
        days_in_range.append(month_date.day)

    hours_of_day = [8, 12, 18]  # Horas representativas de salida

    # Iterar sobre los meses desde el mes actual hasta 12 meses adelante
    for month_offset in range(0, 12):
        month = (start_date.month + month_offset - 1) % 12 + 1  # Asegurar que el mes se envuelve correctamente
        print(f"Revisando mes {month}...")

        month_mean_prices = []  # Lista para almacenar los precios medios del mes actual
        
        # Iterar sobre los días representativos
        for day in days_in_range:
            day_mean_prices = []  # Lista para almacenar los precios medios del día actual
            
            # Iterar sobre las horas del día
            for hour in hours_of_day:
                # Determinar si se necesita una parada según la distancia
                distance = calculate_distance_two(origin, destination)
                stops = 1 if determine_if_stop_needed(distance) else 0

                # Predecir el precio del vuelo para cada combinación
                predicted_price = predecir(Hour_of_Departure=hour, airline='', Stops=stops,
                                           Origin_Country=origin, Destination_Country=destination,
                                           day=day, month=month, year=start_date.year)

                # Calcular el precio medio para la combinación específica de día/hora
                mean_price = np.mean(predicted_price)
                day_mean_prices.append(mean_price)

                print(f"Revisado día {day}, hora {hour} en el mes {month}... Precio Medio: {mean_price}")

            # Almacenar el precio medio del día si es el mejor encontrado hasta ahora en este mes
            month_mean_prices.append(np.mean(day_mean_prices))
        
        # Almacenar los precios medios de este mes en la lista general
        mean_prices_by_month.append(np.mean(month_mean_prices))
        print("Precio medio del mes ",month," ",np.mean(month_mean_prices))

        # Determinar si este mes tiene el precio medio más bajo
        if len(mean_prices_by_month) == 1 or mean_prices_by_month[-1] < np.min(mean_prices_by_month):
            best_month = month
            best_day_index = np.argmin(month_mean_prices)
            best_day = days_in_range[best_day_index]

            print(f"Nuevo mejor mes encontrado: {best_month}, Mejor Día: {best_day}, Precio Medio: {mean_prices_by_month[-1]}")

    # Encontrar el precio medio más bajo entre todos los meses
    
    best_month_index = np.argmin(mean_prices_by_month)

    # Ajustar best_month para asegurar que esté dentro del rango 1-12
    best_month = (start_date.month + best_month_index) % 12 + 1
    best_year = start_date.year + (start_date.month + best_month_index - 1) // 12  # Ajustar el año si el mes se envuelve


    
    day_mean_prices = []
    

    for day in day_of_month:
        hour_mean_prices=[]
        for hour in hours_of_day:
        # Predecir el precio del vuelo para cada hora en el mejor día y mes
            predicted_price = predecir(Hour_of_Departure=hour, airline='', Stops=stops,
                                   Origin_Country=origin, Destination_Country=destination,
                                   day=day, month=best_month, year=start_date.year)

        # Calcular el precio medio para la hora específica
            
            hour_mean_prices.append(predicted_price)

        mean_price_day = np.mean(predicted_price)
        day_mean_prices.append(mean_price_day)

    best_day=np.argmin(day_mean_prices)

    lowest_price=predecir(Hour_of_Departure=hour, airline='', Stops=stops,
                                   Origin_Country=origin, Destination_Country=destination,
                                   day=best_day, month=best_month, year=start_date.year)


    print(f"Mejor momento de viaje encontrado - Mes: {best_month}, Año: {best_year}, Día: {best_day}, Precio Más Bajo: {lowest_price}")

    return best_month, best_day,  lowest_price

# Ejemplo de uso
origin = 'Sweden'
destination = 'Iceland'

best_month, best_day, lowest_price = find_best_travel_time(origin, destination)
print(f"Mejor mes: {best_month}, Mejor día: {best_day}, Precio más bajo: {lowest_price}")
# Out:
# Revisando mes 7...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 7... Precio Medio: 765.0322213893163
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 7... Precio Medio: 734.2551778287446
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 7... Precio Medio: 730.5485877556395
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 7... Precio Medio: 765.017331119044
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 7... Precio Medio: 734.2452861727393
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 7... Precio Medio: 730.548308362375
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 7... Precio Medio: 765.0024509275107
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 7... Precio Medio: 734.2354016977448
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 7... Precio Medio: 730.5480288303876
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 7... Precio Medio: 765.0024509275107
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 7... Precio Medio: 734.2354016977448
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 7... Precio Medio: 730.5480288303876
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 7... Precio Medio: 764.9875880546596
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 7... Precio Medio: 734.2255240976087
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 7... Precio Medio: 730.547750012707
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 7... Precio Medio: 764.9875880546596
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 7... Precio Medio: 734.2255240976087
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 7... Precio Medio: 730.547750012707
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 7... Precio Medio: 764.9727342701311
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 7... Precio Medio: 734.2156529562328
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 7... Precio Medio: 730.5470557745608
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 7... Precio Medio: 764.9578895550279
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 7... Precio Medio: 734.2057885584923
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 7... Precio Medio: 730.5462860369673
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 7... Precio Medio: 764.9875880546596
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 7... Precio Medio: 734.2255240976087
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 7... Precio Medio: 730.547750012707
# Precio medio del mes  7   743.2572840439067
# Nuevo mejor mes encontrado: 7, Mejor Día: 9, Precio Medio: 743.2572840439067
# Revisando mes 8...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 8... Precio Medio: 765.5175902658422
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 8... Precio Medio: 734.5564703644909
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 8... Precio Medio: 669.341909530188
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 8... Precio Medio: 765.5010681429004
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 8... Precio Medio: 734.5491536788114
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 8... Precio Medio: 669.358117806355
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 8... Precio Medio: 765.4845510888257
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 8... Precio Medio: 734.5418474855658
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 8... Precio Medio: 669.3743066829187
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 8... Precio Medio: 765.4845510888257
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 8... Precio Medio: 734.5418474855658
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 8... Precio Medio: 669.3743066829187
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 8... Precio Medio: 765.4680398778721
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 8... Precio Medio: 734.5354962124692
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 8... Precio Medio: 669.3904803695251
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 8... Precio Medio: 765.4680398778721
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 8... Precio Medio: 734.5354962124692
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 8... Precio Medio: 669.3904803695251
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 8... Precio Medio: 765.4515374156457
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 8... Precio Medio: 734.5257113536859
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 8... Precio Medio: 669.3985663478423
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 8... Precio Medio: 765.435043301114
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 8... Precio Medio: 734.5158673411272
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 8... Precio Medio: 669.4046786502242
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 8... Precio Medio: 765.4680398778721
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 8... Precio Medio: 734.5354962124692
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 8... Precio Medio: 669.3904803695251
# Precio medio del mes  8   723.1310805219423
# Revisando mes 9...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 9... Precio Medio: 776.4468965950409
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 9... Precio Medio: 734.8923122992162
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 9... Precio Medio: 668.850657146669
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 9... Precio Medio: 776.436128082845
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 9... Precio Medio: 734.8795407277015
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 9... Precio Medio: 668.8647660851683
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 9... Precio Medio: 776.4253548270516
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 9... Precio Medio: 734.8667819271172
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 9... Precio Medio: 668.8782657175374
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 9... Precio Medio: 776.4253548270516
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 9... Precio Medio: 734.8667819271172
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 9... Precio Medio: 668.8782657175374
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 9... Precio Medio: 776.4145803131892
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 9... Precio Medio: 734.85403586365
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 9... Precio Medio: 668.8908186188123
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 9... Precio Medio: 776.4145803131892
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 9... Precio Medio: 734.85403586365
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 9... Precio Medio: 668.8908186188123
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 9... Precio Medio: 776.40381692725
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 9... Precio Medio: 734.8413025035999
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 9... Precio Medio: 668.9033600122019
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 9... Precio Medio: 776.3930516487226
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 9... Precio Medio: 734.8285827334677
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 9... Precio Medio: 668.9158899149734
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 9... Precio Medio: 776.4145803131892
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 9... Precio Medio: 734.85403586365
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 9... Precio Medio: 668.8908186188123
# Precio medio del mes  9   726.7213116298972
# Revisando mes 10...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 10... Precio Medio: 778.7647422443146
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 10... Precio Medio: 735.1247923701435
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 10... Precio Medio: 668.4103792437712
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 10... Precio Medio: 778.7503976345782
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 10... Precio Medio: 735.1207559713096
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 10... Precio Medio: 668.4272946047521
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 10... Precio Medio: 778.7360493325929
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 10... Precio Medio: 735.1167151089586
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 10... Precio Medio: 668.444196808357
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 10... Precio Medio: 778.7360493325929
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 10... Precio Medio: 735.1167151089586
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 10... Precio Medio: 668.444196808357
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 10... Precio Medio: 778.7217135218045
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 10... Precio Medio: 735.1126697938248
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 10... Precio Medio: 668.4610858744716
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 10... Precio Medio: 778.7217135218045
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 10... Precio Medio: 735.1126697938248
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 10... Precio Medio: 668.4610858744716
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 10... Precio Medio: 778.707379635593
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 10... Precio Medio: 735.1086200366026
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 10... Precio Medio: 668.4779618229385
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 10... Precio Medio: 778.6930409068138
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 10... Precio Medio: 735.104112873988
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 10... Precio Medio: 668.4937051316724
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 10... Precio Medio: 778.7217135218045
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 10... Precio Medio: 735.1126697938248
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 10... Precio Medio: 668.4610858744716
# Precio medio del mes  10   727.4319819461703
# Revisando mes 11...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 11... Precio Medio: 779.0002041327596
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 11... Precio Medio: 735.4345199946475
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 11... Precio Medio: 649.2082515870355
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 11... Precio Medio: 778.9958733305049
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 11... Precio Medio: 735.4217991237308
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 11... Precio Medio: 649.2315444291227
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 11... Precio Medio: 778.9915266258057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 11... Precio Medio: 735.4090845088898
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 11... Precio Medio: 649.2548182146237
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 11... Precio Medio: 778.9915266258057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 11... Precio Medio: 735.4090845088898
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 11... Precio Medio: 649.2548182146237
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 11... Precio Medio: 778.9871640355343
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 11... Precio Medio: 735.3963695032919
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 11... Precio Medio: 649.2780729767604
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 11... Precio Medio: 778.9871640355343
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 11... Precio Medio: 735.3963695032919
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 11... Precio Medio: 649.2780729767604
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 11... Precio Medio: 778.9827868599185
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 11... Precio Medio: 735.3835515075544
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 11... Precio Medio: 649.3013835588417
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 11... Precio Medio: 778.9784073077631
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 11... Precio Medio: 735.37073923705
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 11... Precio Medio: 649.3246998191338
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 11... Precio Medio: 778.9871640355343
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 11... Precio Medio: 735.3963695032919
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 11... Precio Medio: 649.2780729767604
# Precio medio del mes  11   721.2196088567948
# Revisando mes 12...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 12... Precio Medio: 760.5246328926974
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 12... Precio Medio: 695.0597490861912
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 12... Precio Medio: 631.0696466996283
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 12... Precio Medio: 760.5282431540204
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 12... Precio Medio: 695.065928893322
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 12... Precio Medio: 631.0870699858609
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 12... Precio Medio: 760.5376979734654
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 12... Precio Medio: 695.072099432954
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 12... Precio Medio: 631.1044645642099
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 12... Precio Medio: 760.5376979734654
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 12... Precio Medio: 695.072099432954
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 12... Precio Medio: 631.1044645642099
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 12... Precio Medio: 760.5505660440642
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 12... Precio Medio: 695.0782607264262
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 12... Precio Medio: 631.121840157293
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 12... Precio Medio: 760.5505660440642
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 12... Precio Medio: 695.0782607264262
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 12... Precio Medio: 631.121840157293
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 12... Precio Medio: 760.5634183053002
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 12... Precio Medio: 695.0844156641522
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 12... Precio Medio: 631.1391979094534
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 12... Precio Medio: 743.726604029466
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 12... Precio Medio: 695.0905755351921
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 12... Precio Medio: 631.1565395942841
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 12... Precio Medio: 760.5505660440642
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 12... Precio Medio: 695.0782607264262
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 12... Precio Medio: 631.121840157293
# Precio medio del mes  12   694.954686906451
# Revisando mes 1...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 1... Precio Medio: 720.1838046758158
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 1... Precio Medio: 718.184579996521
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 1... Precio Medio: 676.8239512854982
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 1... Precio Medio: 720.1731492187829
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 1... Precio Medio: 718.1822055305582
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 1... Precio Medio: 676.8244909282641
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 1... Precio Medio: 720.162107586801
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 1... Precio Medio: 718.1798350621814
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 1... Precio Medio: 676.8250333685604
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 1... Precio Medio: 720.162107586801
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 1... Precio Medio: 718.1798350621814
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 1... Precio Medio: 676.8250333685604
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 1... Precio Medio: 720.1505912190412
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 1... Precio Medio: 718.1774700959893
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 1... Precio Medio: 676.8255785974559
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 1... Precio Medio: 720.1505912190412
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 1... Precio Medio: 718.1774700959893
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 1... Precio Medio: 676.8255785974559
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 1... Precio Medio: 720.1390836201446
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 1... Precio Medio: 718.1751094159732
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 1... Precio Medio: 676.8261443446959
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 1... Precio Medio: 720.1272390576752
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 1... Precio Medio: 718.1727527034824
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 1... Precio Medio: 676.8267201190231
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 1... Precio Medio: 720.1505912190412
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 1... Precio Medio: 718.1774700959893
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 1... Precio Medio: 676.8255785974559
# Precio medio del mes  1   705.0531149136658
# Revisando mes 2...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 2... Precio Medio: 720.6067304881533
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 2... Precio Medio: 718.4491493202636
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 2... Precio Medio: 676.8719903792762
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 2... Precio Medio: 720.5918560474546
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 2... Precio Medio: 718.4381264576565
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 2... Precio Medio: 676.8702053282253
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 2... Precio Medio: 720.57699375193
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 2... Precio Medio: 718.4271129849462
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 2... Precio Medio: 676.8684271056965
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 2... Precio Medio: 720.57699375193
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 2... Precio Medio: 718.4271129849462
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 2... Precio Medio: 676.8684271056965
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 2... Precio Medio: 720.5621327112766
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 2... Precio Medio: 718.4161114433668
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 2... Precio Medio: 676.8666556921391
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 2... Precio Medio: 720.5621327112766
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 2... Precio Medio: 718.4161114433668
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 2... Precio Medio: 676.8666556921391
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 2... Precio Medio: 720.5472738871678
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 2... Precio Medio: 718.4051214397214
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 2... Precio Medio: 676.8648910680698
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 2... Precio Medio: 720.5324256940063
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 2... Precio Medio: 718.3941404768307
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 2... Precio Medio: 676.8631322179127
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 2... Precio Medio: 720.5621327112766
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 2... Precio Medio: 718.4161114433668
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 2... Precio Medio: 676.8666556921391
# Precio medio del mes  2   705.2857337048233
# Revisando mes 3...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 3... Precio Medio: 721.0496487813085
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 3... Precio Medio: 718.7696575968081
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 3... Precio Medio: 676.9053037800871
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 3... Precio Medio: 721.0334801421156
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 3... Precio Medio: 718.758514626948
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 3... Precio Medio: 676.9064793766216
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 3... Precio Medio: 721.01732256738
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 3... Precio Medio: 718.7473809946937
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 3... Precio Medio: 676.9076716042881
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 3... Precio Medio: 721.01732256738
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 3... Precio Medio: 718.7473809946937
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 3... Precio Medio: 676.9076716042881
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 3... Precio Medio: 721.0011762307453
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 3... Precio Medio: 718.7362566864148
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 3... Precio Medio: 676.9088669769914
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 3... Precio Medio: 721.0011762307453
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 3... Precio Medio: 718.7362566864148
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 3... Precio Medio: 676.9088669769914
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 3... Precio Medio: 720.9850411208243
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 3... Precio Medio: 718.7251416885127
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 3... Precio Medio: 676.9100654815836
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 3... Precio Medio: 720.9689172262458
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 3... Precio Medio: 718.7140359874198
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 3... Precio Medio: 676.9107247153333
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 3... Precio Medio: 721.0011762307453
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 3... Precio Medio: 718.7362566864148
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 3... Precio Medio: 676.9088669769914
# Precio medio del mes  3   705.5526170569996
# Revisando mes 4...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 4... Precio Medio: 721.5133577518382
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 4... Precio Medio: 719.0942449008901
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 4... Precio Medio: 655.5168677263849
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 4... Precio Medio: 721.5001895957876
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 4... Precio Medio: 719.083429937875
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 4... Precio Medio: 655.52898524642
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 4... Precio Medio: 721.4870397511486
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 4... Precio Medio: 719.0727210151096
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 4... Precio Medio: 655.5410916503479
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 4... Precio Medio: 721.4870397511486
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 4... Precio Medio: 719.0727210151096
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 4... Precio Medio: 655.5410916503479
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 4... Precio Medio: 721.4739034407958
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 4... Precio Medio: 719.0621615890122
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 4... Precio Medio: 655.553188134511
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 4... Precio Medio: 721.4739034407958
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 4... Precio Medio: 719.0621615890122
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 4... Precio Medio: 655.553188134511
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 4... Precio Medio: 721.4607592450915
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 4... Precio Medio: 719.0516447986989
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 4... Precio Medio: 655.5652708467046
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 4... Precio Medio: 721.4476077484792
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 4... Precio Medio: 719.0411467159443
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 4... Precio Medio: 655.5773397916616
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 4... Precio Medio: 721.4739034407958
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 4... Precio Medio: 719.0621615890122
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 4... Precio Medio: 655.553188134511
# Precio medio del mes  4   698.6981595789608
# Revisando mes 5...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 5... Precio Medio: 736.1471742038295
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 5... Precio Medio: 719.353519719467
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 5... Precio Medio: 687.2149868977806
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 5... Precio Medio: 736.1450419329545
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 5... Precio Medio: 719.3502942046651
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 5... Precio Medio: 687.2146617170141
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 5... Precio Medio: 736.1428922096977
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 5... Precio Medio: 719.3470664757057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 5... Precio Medio: 687.2136000698291
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 5... Precio Medio: 736.1428922096977
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 5... Precio Medio: 719.3470664757057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 5... Precio Medio: 687.2136000698291
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 5... Precio Medio: 736.1405048363607
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 5... Precio Medio: 719.3438398313905
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 5... Precio Medio: 687.2125376575244
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 5... Precio Medio: 736.1405048363607
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 5... Precio Medio: 719.3438398313905
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 5... Precio Medio: 687.2125376575244
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 5... Precio Medio: 721.8168242737157
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 5... Precio Medio: 719.3406965072088
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 5... Precio Medio: 687.2114744865145
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 5... Precio Medio: 721.8052165503259
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 5... Precio Medio: 719.337717904404
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 5... Precio Medio: 687.2104105631836
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 5... Precio Medio: 736.1405048363607
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 5... Precio Medio: 719.3438398313905
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 5... Precio Medio: 687.2125376575244
# Precio medio del mes  5   713.1720660536057
# Revisando mes 6...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 6... Precio Medio: 764.6931404770725
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 6... Precio Medio: 733.6616468655291
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 6... Precio Medio: 687.1325691773754
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 6... Precio Medio: 764.6872365657676
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 6... Precio Medio: 733.660232982485
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 6... Precio Medio: 687.1345062373308
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 6... Precio Medio: 764.681321748667
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 6... Precio Medio: 733.6588113933879
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 6... Precio Medio: 687.136850192609
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 6... Precio Medio: 764.681321748667
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 6... Precio Medio: 733.6588113933879
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 6... Precio Medio: 687.136850192609
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 6... Precio Medio: 764.6750319496988
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 6... Precio Medio: 733.6573821196155
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 6... Precio Medio: 687.139193010362
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 6... Precio Medio: 764.6750319496988
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 6... Precio Medio: 733.6573821196155
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 6... Precio Medio: 687.139193010362
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 6... Precio Medio: 764.6683438750015
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 6... Precio Medio: 733.6559481790536
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 6... Precio Medio: 687.1415359225921
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 6... Precio Medio: 764.6616639154613
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 6... Precio Medio: 733.654509387361
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 6... Precio Medio: 687.1443342040577
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 6... Precio Medio: 764.6750319496988
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 6... Precio Medio: 733.6573821196155
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 6... Precio Medio: 687.139193010362
# Precio medio del mes  6   728.4912761369422
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# Mejor momento de viaje encontrado - Mes: 1, Año: 2024, Día: 13, Precio Más Bajo: [676.82449093]
# Mejor mes: 1, Mejor día: 13, Precio más bajo: [676.82449093]

# %% [markdown]
# Sin mes ni dia

# %%
from datetime import datetime, timedelta
import numpy as np
import warnings

# Suprimir todas las advertencias
warnings.filterwarnings('ignore')

def calculate_distance_two(origin_country, destination_country):
    origin_lat, origin_lon = get_airport_coordinates(origin_country)
    destination_lat, destination_lon = get_airport_coordinates(destination_country)
    
    if origin_lat is not None and destination_lat is not None:
        return haversine(origin_lat, origin_lon, destination_lat, destination_lon)
    
    return None

def determine_if_stop_needed(distance):
    # Definir el umbral de distancia para requerir una parada
    stop_threshold = 6437.376  # Ejemplo de umbral en kilómetros

    # Determinar si se necesita una parada según la distancia
    if distance > stop_threshold:
        return True
    else:
        return False

def find_best_travel_time(origin, destination):
    best_month = None
    best_day = None
    best_hour = None

    # Inicializar una lista vacía para almacenar los precios medios por mes
    mean_prices_by_month = []

    # Calcular el rango de fechas desde hoy hasta un año a partir de ahora
    start_date = datetime.now()
    end_date = start_date + timedelta(days=365)  # Un año desde ahora

    day_of_month=np.arange(1,30)
    # Días representativos (1 por mes)
    days_in_range = []
    for i in range(9):  # Ajustar el número de días representativos según sea necesario
        # Calcular el día para cada mes representativo
        month_date = start_date + timedelta(days=i * 30)  # Aproximación de días en un mes
        days_in_range.append(month_date.day)

    hours_of_day = [8, 12, 18]  # Horas representativas de salida

    # Iterar sobre los meses desde el mes actual hasta 12 meses adelante
    for month_offset in range(0, 12):
        month = (start_date.month + month_offset - 1) % 12 + 1  # Asegurar que el mes se envuelve correctamente
        print(f"Revisando mes {month}...")

        month_mean_prices = []  # Lista para almacenar los precios medios del mes actual
        
        # Iterar sobre los días representativos
        for day in days_in_range:
            day_mean_prices = []  # Lista para almacenar los precios medios del día actual
            
            # Iterar sobre las horas del día
            for hour in hours_of_day:
                # Determinar si se necesita una parada según la distancia
                distance = calculate_distance_two(origin, destination)
                stops = 1 if determine_if_stop_needed(distance) else 0

                # Predecir el precio del vuelo para cada combinación
                predicted_price = predecir_nmd(Hour_of_Departure=hour, airline='', Stops=stops,
                                           Origin_Country=origin, Destination_Country=destination,
                                           day=day, month=month, year=start_date.year)

                # Calcular el precio medio para la combinación específica de día/hora
                mean_price = np.mean(predicted_price)
                day_mean_prices.append(mean_price)

                print(f"Revisado día {day}, hora {hour} en el mes {month}... Precio Medio: {mean_price}")

            # Almacenar el precio medio del día si es el mejor encontrado hasta ahora en este mes
            month_mean_prices.append(np.mean(day_mean_prices))
        
        # Almacenar los precios medios de este mes en la lista general
        mean_prices_by_month.append(np.mean(month_mean_prices))
        print("Precio medio del mes ",month," ",np.mean(month_mean_prices))

        # Determinar si este mes tiene el precio medio más bajo
        if len(mean_prices_by_month) == 1 or mean_prices_by_month[-1] < np.min(mean_prices_by_month):
            best_month = month
            best_day_index = np.argmin(month_mean_prices)
            best_day = days_in_range[best_day_index]

            print(f"Nuevo mejor mes encontrado: {best_month}, Mejor Día: {best_day}, Precio Medio: {mean_prices_by_month[-1]}")

    # Encontrar el precio medio más bajo entre todos los meses
    
    best_month_index = np.argmin(mean_prices_by_month)

    # Ajustar best_month para asegurar que esté dentro del rango 1-12
    best_month = (start_date.month + best_month_index) % 12 + 1
    best_year = start_date.year + (start_date.month + best_month_index - 1) // 12  # Ajustar el año si el mes se envuelve


    
    day_mean_prices = []
    

    for day in day_of_month:
        hour_mean_prices=[]
        for hour in hours_of_day:
        # Predecir el precio del vuelo para cada hora en el mejor día y mes
            predicted_price = predecir_nmd(Hour_of_Departure=hour, airline='', Stops=stops,
                                   Origin_Country=origin, Destination_Country=destination,
                                   day=day, month=best_month, year=start_date.year)

        # Calcular el precio medio para la hora específica
            
            hour_mean_prices.append(predicted_price)

        mean_price_day = np.mean(predicted_price)
        day_mean_prices.append(mean_price_day)

    best_day=np.argmin(day_mean_prices)

    lowest_price=predecir_nmd(Hour_of_Departure=hour, airline='', Stops=stops,
                                   Origin_Country=origin, Destination_Country=destination,
                                   day=best_day, month=best_month, year=start_date.year)


    print(f"Mejor momento de viaje encontrado - Mes: {best_month}, Año: {best_year}, Día: {best_day}, Precio Más Bajo: {lowest_price}")

    return best_month, best_day,  lowest_price

# Ejemplo de uso
origin = 'Sweden'
destination = 'Iceland'

best_month, best_day, lowest_price = find_best_travel_time(origin, destination)
print(f"Mejor mes: {best_month}, Mejor día: {best_day}, Precio más bajo: {lowest_price}")
# Out:
# Revisando mes 7...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 7... Precio Medio: 765.0322213893163
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 7... Precio Medio: 734.2551778287446
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 7... Precio Medio: 730.5485877556395
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 7... Precio Medio: 765.017331119044
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 7... Precio Medio: 734.2452861727393
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 7... Precio Medio: 730.548308362375
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 7... Precio Medio: 765.0024509275107
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 7... Precio Medio: 734.2354016977448
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 7... Precio Medio: 730.5480288303876
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 7... Precio Medio: 765.0024509275107
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 7... Precio Medio: 734.2354016977448
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 7... Precio Medio: 730.5480288303876
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 7... Precio Medio: 764.9875880546596
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 7... Precio Medio: 734.2255240976087
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 7... Precio Medio: 730.547750012707
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 7... Precio Medio: 764.9875880546596
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 7... Precio Medio: 734.2255240976087
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 7... Precio Medio: 730.547750012707
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 7... Precio Medio: 764.9727342701311
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 7... Precio Medio: 734.2156529562328
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 7... Precio Medio: 730.5470557745608
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 7... Precio Medio: 764.9578895550279
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 7... Precio Medio: 734.2057885584923
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 7... Precio Medio: 730.5462860369673
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 7... Precio Medio: 764.9875880546596
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 7... Precio Medio: 734.2255240976087
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 7... Precio Medio: 730.547750012707
# Precio medio del mes  7   743.2572840439067
# Nuevo mejor mes encontrado: 7, Mejor Día: 9, Precio Medio: 743.2572840439067
# Revisando mes 8...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 8... Precio Medio: 765.5175902658422
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 8... Precio Medio: 734.5564703644909
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 8... Precio Medio: 669.341909530188
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 8... Precio Medio: 765.5010681429004
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 8... Precio Medio: 734.5491536788114
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 8... Precio Medio: 669.358117806355
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 8... Precio Medio: 765.4845510888257
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 8... Precio Medio: 734.5418474855658
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 8... Precio Medio: 669.3743066829187
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 8... Precio Medio: 765.4845510888257
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 8... Precio Medio: 734.5418474855658
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 8... Precio Medio: 669.3743066829187
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 8... Precio Medio: 765.4680398778721
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 8... Precio Medio: 734.5354962124692
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 8... Precio Medio: 669.3904803695251
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 8... Precio Medio: 765.4680398778721
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 8... Precio Medio: 734.5354962124692
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 8... Precio Medio: 669.3904803695251
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 8... Precio Medio: 765.4515374156457
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 8... Precio Medio: 734.5257113536859
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 8... Precio Medio: 669.3985663478423
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 8... Precio Medio: 765.435043301114
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 8... Precio Medio: 734.5158673411272
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 8... Precio Medio: 669.4046786502242
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 8... Precio Medio: 765.4680398778721
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 8... Precio Medio: 734.5354962124692
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 8... Precio Medio: 669.3904803695251
# Precio medio del mes  8   723.1310805219423
# Revisando mes 9...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 9... Precio Medio: 776.4468965950409
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 9... Precio Medio: 734.8923122992162
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 9... Precio Medio: 668.850657146669
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 9... Precio Medio: 776.436128082845
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 9... Precio Medio: 734.8795407277015
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 9... Precio Medio: 668.8647660851683
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 9... Precio Medio: 776.4253548270516
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 9... Precio Medio: 734.8667819271172
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 9... Precio Medio: 668.8782657175374
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 9... Precio Medio: 776.4253548270516
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 9... Precio Medio: 734.8667819271172
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 9... Precio Medio: 668.8782657175374
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 9... Precio Medio: 776.4145803131892
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 9... Precio Medio: 734.85403586365
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 9... Precio Medio: 668.8908186188123
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 9... Precio Medio: 776.4145803131892
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 9... Precio Medio: 734.85403586365
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 9... Precio Medio: 668.8908186188123
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 9... Precio Medio: 776.40381692725
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 9... Precio Medio: 734.8413025035999
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 9... Precio Medio: 668.9033600122019
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 9... Precio Medio: 776.3930516487226
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 9... Precio Medio: 734.8285827334677
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 9... Precio Medio: 668.9158899149734
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 9... Precio Medio: 776.4145803131892
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 9... Precio Medio: 734.85403586365
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 9... Precio Medio: 668.8908186188123
# Precio medio del mes  9   726.7213116298972
# Revisando mes 10...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 10... Precio Medio: 778.7647422443146
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 10... Precio Medio: 735.1247923701435
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 10... Precio Medio: 668.4103792437712
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 10... Precio Medio: 778.7503976345782
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 10... Precio Medio: 735.1207559713096
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 10... Precio Medio: 668.4272946047521
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 10... Precio Medio: 778.7360493325929
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 10... Precio Medio: 735.1167151089586
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 10... Precio Medio: 668.444196808357
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 10... Precio Medio: 778.7360493325929
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 10... Precio Medio: 735.1167151089586
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 10... Precio Medio: 668.444196808357
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 10... Precio Medio: 778.7217135218045
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 10... Precio Medio: 735.1126697938248
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 10... Precio Medio: 668.4610858744716
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 10... Precio Medio: 778.7217135218045
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 10... Precio Medio: 735.1126697938248
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 10... Precio Medio: 668.4610858744716
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 10... Precio Medio: 778.707379635593
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 10... Precio Medio: 735.1086200366026
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 10... Precio Medio: 668.4779618229385
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 10... Precio Medio: 778.6930409068138
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 10... Precio Medio: 735.104112873988
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 10... Precio Medio: 668.4937051316724
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 10... Precio Medio: 778.7217135218045
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 10... Precio Medio: 735.1126697938248
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 10... Precio Medio: 668.4610858744716
# Precio medio del mes  10   727.4319819461703
# Revisando mes 11...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 11... Precio Medio: 779.0002041327596
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 11... Precio Medio: 735.4345199946475
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 11... Precio Medio: 649.2082515870355
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 11... Precio Medio: 778.9958733305049
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 11... Precio Medio: 735.4217991237308
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 11... Precio Medio: 649.2315444291227
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 11... Precio Medio: 778.9915266258057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 11... Precio Medio: 735.4090845088898
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 11... Precio Medio: 649.2548182146237
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 11... Precio Medio: 778.9915266258057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 11... Precio Medio: 735.4090845088898
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 11... Precio Medio: 649.2548182146237
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 11... Precio Medio: 778.9871640355343
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 11... Precio Medio: 735.3963695032919
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 11... Precio Medio: 649.2780729767604
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 11... Precio Medio: 778.9871640355343
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 11... Precio Medio: 735.3963695032919
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 11... Precio Medio: 649.2780729767604
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 11... Precio Medio: 778.9827868599185
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 11... Precio Medio: 735.3835515075544
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 11... Precio Medio: 649.3013835588417
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 11... Precio Medio: 778.9784073077631
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 11... Precio Medio: 735.37073923705
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 11... Precio Medio: 649.3246998191338
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 11... Precio Medio: 778.9871640355343
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 11... Precio Medio: 735.3963695032919
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 11... Precio Medio: 649.2780729767604
# Precio medio del mes  11   721.2196088567948
# Revisando mes 12...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 12... Precio Medio: 760.5246328926974
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 12... Precio Medio: 695.0597490861912
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 12... Precio Medio: 631.0696466996283
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 12... Precio Medio: 760.5282431540204
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 12... Precio Medio: 695.065928893322
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 12... Precio Medio: 631.0870699858609
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 12... Precio Medio: 760.5376979734654
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 12... Precio Medio: 695.072099432954
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 12... Precio Medio: 631.1044645642099
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 12... Precio Medio: 760.5376979734654
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 12... Precio Medio: 695.072099432954
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 12... Precio Medio: 631.1044645642099
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 12... Precio Medio: 760.5505660440642
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 12... Precio Medio: 695.0782607264262
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 12... Precio Medio: 631.121840157293
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 12... Precio Medio: 760.5505660440642
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 12... Precio Medio: 695.0782607264262
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 12... Precio Medio: 631.121840157293
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 12... Precio Medio: 760.5634183053002
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 12... Precio Medio: 695.0844156641522
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 12... Precio Medio: 631.1391979094534
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 12... Precio Medio: 743.726604029466
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 12... Precio Medio: 695.0905755351921
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 12... Precio Medio: 631.1565395942841
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 12... Precio Medio: 760.5505660440642
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 12... Precio Medio: 695.0782607264262
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 12... Precio Medio: 631.121840157293
# Precio medio del mes  12   694.954686906451
# Revisando mes 1...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 1... Precio Medio: 720.1838046758158
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 1... Precio Medio: 718.184579996521
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 1... Precio Medio: 676.8239512854982
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 1... Precio Medio: 720.1731492187829
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 1... Precio Medio: 718.1822055305582
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 1... Precio Medio: 676.8244909282641
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 1... Precio Medio: 720.162107586801
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 1... Precio Medio: 718.1798350621814
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 1... Precio Medio: 676.8250333685604
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 1... Precio Medio: 720.162107586801
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 1... Precio Medio: 718.1798350621814
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 1... Precio Medio: 676.8250333685604
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 1... Precio Medio: 720.1505912190412
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 1... Precio Medio: 718.1774700959893
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 1... Precio Medio: 676.8255785974559
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 1... Precio Medio: 720.1505912190412
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 1... Precio Medio: 718.1774700959893
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 1... Precio Medio: 676.8255785974559
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 1... Precio Medio: 720.1390836201446
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 1... Precio Medio: 718.1751094159732
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 1... Precio Medio: 676.8261443446959
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 1... Precio Medio: 720.1272390576752
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 1... Precio Medio: 718.1727527034824
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 1... Precio Medio: 676.8267201190231
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 1... Precio Medio: 720.1505912190412
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 1... Precio Medio: 718.1774700959893
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 1... Precio Medio: 676.8255785974559
# Precio medio del mes  1   705.0531149136658
# Revisando mes 2...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 2... Precio Medio: 720.6067304881533
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 2... Precio Medio: 718.4491493202636
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 2... Precio Medio: 676.8719903792762
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 2... Precio Medio: 720.5918560474546
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 2... Precio Medio: 718.4381264576565
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 2... Precio Medio: 676.8702053282253
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 2... Precio Medio: 720.57699375193
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 2... Precio Medio: 718.4271129849462
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 2... Precio Medio: 676.8684271056965
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 2... Precio Medio: 720.57699375193
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 2... Precio Medio: 718.4271129849462
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 2... Precio Medio: 676.8684271056965
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 2... Precio Medio: 720.5621327112766
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 2... Precio Medio: 718.4161114433668
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 2... Precio Medio: 676.8666556921391
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 2... Precio Medio: 720.5621327112766
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 2... Precio Medio: 718.4161114433668
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 2... Precio Medio: 676.8666556921391
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 2... Precio Medio: 720.5472738871678
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 2... Precio Medio: 718.4051214397214
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 2... Precio Medio: 676.8648910680698
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 2... Precio Medio: 720.5324256940063
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 2... Precio Medio: 718.3941404768307
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 2... Precio Medio: 676.8631322179127
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 2... Precio Medio: 720.5621327112766
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 2... Precio Medio: 718.4161114433668
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 2... Precio Medio: 676.8666556921391
# Precio medio del mes  2   705.2857337048233
# Revisando mes 3...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 3... Precio Medio: 721.0496487813085
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 3... Precio Medio: 718.7696575968081
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 3... Precio Medio: 676.9053037800871
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 3... Precio Medio: 721.0334801421156
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 3... Precio Medio: 718.758514626948
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 3... Precio Medio: 676.9064793766216
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 3... Precio Medio: 721.01732256738
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 3... Precio Medio: 718.7473809946937
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 3... Precio Medio: 676.9076716042881
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 3... Precio Medio: 721.01732256738
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 3... Precio Medio: 718.7473809946937
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 3... Precio Medio: 676.9076716042881
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 3... Precio Medio: 721.0011762307453
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 3... Precio Medio: 718.7362566864148
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 3... Precio Medio: 676.9088669769914
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 3... Precio Medio: 721.0011762307453
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 3... Precio Medio: 718.7362566864148
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 3... Precio Medio: 676.9088669769914
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 3... Precio Medio: 720.9850411208243
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 3... Precio Medio: 718.7251416885127
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 3... Precio Medio: 676.9100654815836
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 3... Precio Medio: 720.9689172262458
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 3... Precio Medio: 718.7140359874198
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 3... Precio Medio: 676.9107247153333
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 3... Precio Medio: 721.0011762307453
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 3... Precio Medio: 718.7362566864148
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 3... Precio Medio: 676.9088669769914
# Precio medio del mes  3   705.5526170569996
# Revisando mes 4...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 4... Precio Medio: 721.5133577518382
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 4... Precio Medio: 719.0942449008901
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 4... Precio Medio: 655.5168677263849
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 4... Precio Medio: 721.5001895957876
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 4... Precio Medio: 719.083429937875
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 4... Precio Medio: 655.52898524642
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 4... Precio Medio: 721.4870397511486
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 4... Precio Medio: 719.0727210151096
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 4... Precio Medio: 655.5410916503479
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 4... Precio Medio: 721.4870397511486
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 4... Precio Medio: 719.0727210151096
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 4... Precio Medio: 655.5410916503479
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 4... Precio Medio: 721.4739034407958
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 4... Precio Medio: 719.0621615890122
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 4... Precio Medio: 655.553188134511
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 4... Precio Medio: 721.4739034407958
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 4... Precio Medio: 719.0621615890122
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 4... Precio Medio: 655.553188134511
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 4... Precio Medio: 721.4607592450915
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 4... Precio Medio: 719.0516447986989
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 4... Precio Medio: 655.5652708467046
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 4... Precio Medio: 721.4476077484792
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 4... Precio Medio: 719.0411467159443
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 4... Precio Medio: 655.5773397916616
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 4... Precio Medio: 721.4739034407958
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 4... Precio Medio: 719.0621615890122
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 4... Precio Medio: 655.553188134511
# Precio medio del mes  4   698.6981595789608
# Revisando mes 5...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 5... Precio Medio: 736.1471742038295
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 5... Precio Medio: 719.353519719467
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 5... Precio Medio: 687.2149868977806
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 5... Precio Medio: 736.1450419329545
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 5... Precio Medio: 719.3502942046651
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 5... Precio Medio: 687.2146617170141
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 5... Precio Medio: 736.1428922096977
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 5... Precio Medio: 719.3470664757057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 5... Precio Medio: 687.2136000698291
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 5... Precio Medio: 736.1428922096977
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 5... Precio Medio: 719.3470664757057
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 5... Precio Medio: 687.2136000698291
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 5... Precio Medio: 736.1405048363607
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 5... Precio Medio: 719.3438398313905
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 5... Precio Medio: 687.2125376575244
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 5... Precio Medio: 736.1405048363607
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 5... Precio Medio: 719.3438398313905
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 5... Precio Medio: 687.2125376575244
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 5... Precio Medio: 721.8168242737157
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 5... Precio Medio: 719.3406965072088
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 5... Precio Medio: 687.2114744865145
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 5... Precio Medio: 721.8052165503259
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 5... Precio Medio: 719.337717904404
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 5... Precio Medio: 687.2104105631836
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 5... Precio Medio: 736.1405048363607
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 5... Precio Medio: 719.3438398313905
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 5... Precio Medio: 687.2125376575244
# Precio medio del mes  5   713.1720660536057
# Revisando mes 6...
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 8 en el mes 6... Precio Medio: 764.6931404770725
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 12 en el mes 6... Precio Medio: 733.6616468655291
# ARN
# KEF
# ARN
# KEF
# Revisado día 14, hora 18 en el mes 6... Precio Medio: 687.1325691773754
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 8 en el mes 6... Precio Medio: 764.6872365657676
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 12 en el mes 6... Precio Medio: 733.660232982485
# ARN
# KEF
# ARN
# KEF
# Revisado día 13, hora 18 en el mes 6... Precio Medio: 687.1345062373308
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 6... Precio Medio: 764.681321748667
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 6... Precio Medio: 733.6588113933879
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 6... Precio Medio: 687.136850192609
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 8 en el mes 6... Precio Medio: 764.681321748667
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 12 en el mes 6... Precio Medio: 733.6588113933879
# ARN
# KEF
# ARN
# KEF
# Revisado día 12, hora 18 en el mes 6... Precio Medio: 687.136850192609
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 6... Precio Medio: 764.6750319496988
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 6... Precio Medio: 733.6573821196155
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 6... Precio Medio: 687.139193010362
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 6... Precio Medio: 764.6750319496988
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 6... Precio Medio: 733.6573821196155
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 6... Precio Medio: 687.139193010362
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 8 en el mes 6... Precio Medio: 764.6683438750015
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 12 en el mes 6... Precio Medio: 733.6559481790536
# ARN
# KEF
# ARN
# KEF
# Revisado día 10, hora 18 en el mes 6... Precio Medio: 687.1415359225921
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 8 en el mes 6... Precio Medio: 764.6616639154613
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 12 en el mes 6... Precio Medio: 733.654509387361
# ARN
# KEF
# ARN
# KEF
# Revisado día 9, hora 18 en el mes 6... Precio Medio: 687.1443342040577
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 8 en el mes 6... Precio Medio: 764.6750319496988
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 12 en el mes 6... Precio Medio: 733.6573821196155
# ARN
# KEF
# ARN
# KEF
# Revisado día 11, hora 18 en el mes 6... Precio Medio: 687.139193010362
# Precio medio del mes  6   728.4912761369422
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# ARN
# KEF
# Mejor momento de viaje encontrado - Mes: 1, Año: 2024, Día: 13, Precio Más Bajo: [676.82449093]
# Mejor mes: 1, Mejor día: 13, Precio más bajo: [676.82449093]
